# %% [markdown]
# # **Basic ML for dataset**

# %% [markdown]
# # **Load data**

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/master/BostonHousing.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# # **Data preparation**

# %% [markdown]
# ## Data separation as X and y

# %%
y = df['age']
y
# Out:
# 0      65.2
# 1      78.9
# 2      61.1
# 3      45.8
# 4      54.2
#        ...
# 501    69.1
# 502    76.7
# 503    91.0
# 504    89.3
# 505    80.8
# Name: age, Length: 506, dtype: float64

# %%
X = df.drop('age', axis=1)
X
# Out:
#         crim    zn  indus  chas    nox     rm     dis  rad  tax  ptratio  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07     0  0.469  6.421  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07     0  0.469  7.185  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18     0  0.458  6.998  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18     0  0.458  7.147  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...    ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  2.5050    1  273     21.0
#
#           b  lstat  medv
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 4    396.90   5.33  36.2
# ..      ...    ...   ...
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9
#
# [506 rows x 13 columns]

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#          crim    zn  indus  chas     nox     rm     dis  rad  tax  ptratio  \
# 379  17.86670   0.0  18.10     0  0.6710  6.223  1.3861   24  666     20.2
# 311   0.79041   0.0   9.90     0  0.5440  6.122  2.6403    4  304     18.4
# 157   1.22358   0.0  19.58     0  0.6050  6.943  1.8773    5  403     14.7
# 244   0.20608  22.0   5.86     0  0.4310  5.593  7.9549    7  330     19.1
# 56    0.02055  85.0   0.74     0  0.4100  6.383  9.1876    2  313     17.3
# ..        ...   ...    ...   ...     ...    ...     ...  ...  ...      ...
# 343   0.02543  55.0   3.78     0  0.4840  6.696  5.7321    5  370     17.6
# 359   4.26131   0.0  18.10     0  0.7700  6.112  2.5091   24  666     20.2
# 323   0.28392   0.0   7.38     0  0.4930  5.708  4.7211    5  287     19.6
# 280   0.03578  20.0   3.33     0  0.4429  7.820  4.6947    5  216     14.9
# 8     0.21124  12.5   7.87     0  0.5240  5.631  6.0821    5  311     15.2
#
#           b  lstat  medv
# 379  393.74  21.78  10.2
# 311  396.90   5.98  22.1
# 157  363.43   4.59  41.3
# 244  372.49  12.50  17.6
# 56   396.90   5.77  24.7
# ..      ...    ...   ...
# 343  396.90   7.18  23.9
# 359  390.74  12.67  22.6
# 323  391.13  11.74  18.5
# 280  387.31   3.76  45.4
# 8    386.63  29.93  16.5
#
# [404 rows x 13 columns]

# %%
X_test
# Out:
#          crim    zn  indus  chas    nox     rm     dis  rad  tax  ptratio  \
# 198   0.03768  80.0   1.52     0  0.404  7.274  7.3090    2  329     12.6
# 229   0.44178   0.0   6.20     0  0.504  6.552  3.3751    8  307     17.4
# 502   0.04527   0.0  11.93     0  0.573  6.120  2.2875    1  273     21.0
# 31    1.35472   0.0   8.14     0  0.538  6.072  4.1750    4  307     21.0
# 315   0.25356   0.0   9.90     0  0.544  5.705  3.9450    4  304     18.4
# ..        ...   ...    ...   ...    ...    ...     ...  ...  ...      ...
# 166   2.01019   0.0  19.58     0  0.605  7.929  2.0459    5  403     14.7
# 401  14.23620   0.0  18.10     0  0.693  6.343  1.5741   24  666     20.2
# 368   4.89822   0.0  18.10     0  0.631  4.970  1.3325   24  666     20.2
# 140   0.29090   0.0  21.89     0  0.624  6.174  1.6119    4  437     21.2
# 428   7.36711   0.0  18.10     0  0.679  6.193  1.9356   24  666     20.2
#
#           b  lstat  medv
# 198  392.20   6.62  34.6
# 229  380.34   3.76  31.5
# 502  396.90   9.08  20.6
# 31   376.73  13.04  14.5
# 315  396.42  11.50  16.2
# ..      ...    ...   ...
# 166  369.30   3.70  50.0
# 401  396.90  20.32   7.2
# 368  375.52   3.26  50.0
# 140  388.08  24.16  14.0
# 428   96.73  21.52  11.0
#
# [102 rows x 13 columns]

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# ### **Training the model**

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Applying the model to make a prediction**

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
y_lr_train_pred
# Out:
# array([100.36521136,  67.36169614,  73.59940396,  34.27163916,
#         15.34543712,  95.5005749 , 100.45111139,  67.64536975,
#         51.86475004,  49.21330421,  19.22811764, 100.68843537,
#         63.34660036,  64.25062605,  62.4699801 ,  46.36689291,
#         80.75175473, 102.2200968 ,  96.25807179,  91.25607947,
#         57.99471947,  57.5302176 ,  76.9447596 , 119.99956642,
#         96.32416282,  86.23444066,  56.15394642,  43.53634563,
#         65.56468652,  67.50270224,  40.19120442,  71.23612541,
#         71.86981307,  35.52283499,  81.41137595,  73.61130704,
#         81.12114792,  63.53889796,  76.23357437,  96.28777462,
#         91.17399034,  38.68699034,  34.14218503,  71.1321745 ,
#         78.60063827,  57.47523311,  85.6147069 ,  67.61111178,
#         94.73909051,  48.13659414,  83.09040897,  54.72358122,
#         86.58354956,  22.25392824,  56.45913666,  92.27220133,
#         81.85483121,  97.22615329,  67.84749585,  65.97453375,
#         64.831553  ,  94.23749058,  31.70305709,  45.23045897,
#         81.46023886,  51.45965211,   8.78470967,  90.78411189,
#         69.20975893,  29.61635555,  59.63055645,  47.18290754,
#         44.8310587 ,  50.97879169,  66.13875858, 100.46435792,
#         65.86945098,  50.55884069,  35.23212021,  99.83316514,
#         11.3124845 ,  73.65179965,  48.81489274,  72.83704071,
#         76.06555019,  72.14516455,  65.37584778,  81.156217  ,
#         98.68963616,  78.92400888, 103.53892849,  75.23563682,
#         96.44634935,  41.17407601,  42.17975832,  61.30027999,
#         56.4444985 ,  37.62912333,  61.85637029, 106.35393146,
#         80.11464986,  77.49016773, 100.43649331,  61.72721468,
#        103.81776976,  92.61371285])

# %% [markdown]
# ### **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  250.91101612917066
# LR R2 (Train):  0.6814391600675829
# LR MSE (Test):  276.8877202536133
# LR R2 (Test):  0.6547494574080994

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2   Test MSE   Test R2
# 0  Linear regression   250.911016    0.681439  276.88772  0.654749

# %% [markdown]
# ## **Random Forest**

# %% [markdown]
# ### **Training the model**

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### **Applying the model to make a prediction**

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %% [markdown]
# ### **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2    Test MSE   Test R2
# 0  Random forest   200.948905    0.744872  237.056073  0.704415

# %% [markdown]
# ## **Model comparison**

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)

# %%
df_models.reset_index(drop=True)
# Out:
#               Method Training MSE Training R2    Test MSE   Test R2
# 0  Linear regression   250.911016    0.681439   276.88772  0.654749
# 1      Random forest   200.948905    0.744872  237.056073  0.704415

# %% [markdown]
# # **Data visualization of prediction results**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, c="#EF4040" ,alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict age')
plt.xlabel('Experimental age')
# Out:
# Text(0.5, 0, 'Experimental age')

# %%
# prompt: make the above model display using matplotlib i need it in pie chart

import matplotlib.pyplot as plt
plt.pie(df_models['Test R2'], labels=df_models['Method'])
plt.show()
